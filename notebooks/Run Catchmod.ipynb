# %%
import numpy as np
import pandas
import os
from pycatchmod.io.json import catchment_from_json
from collections import defaultdict

# %%
JSON_DIR = '../hydraville/json'
DATA_DIR = '../data'
CATCHMOD_DIR = os.path.join(JSON_DIR, 'catchmod')

# %%
def generate_catchmod_models():

    for filename in sorted(os.listdir(CATCHMOD_DIR)):
        base, ext = os.path.splitext(filename)
        if ext != '.json':
            continue

        yield catchment_from_json(os.path.join(CATCHMOD_DIR, filename))
        
models = [c for c in generate_catchmod_models()]
# Out:
# C:\Anaconda3\lib\site-packages\pycatchmod\io\json.py:35: UserWarning: Small or zero linear_storage_constant is invalid. Assuming no linear store.
#   legacy=data.get("legacy", False)
# C:\Anaconda3\lib\site-packages\pycatchmod\io\json.py:35: UserWarning: Small or zero nonlinear_storage_constant is invalid. Assuming no non-linear store.
#   legacy=data.get("legacy", False)

# %%
def run_catchmod(C, rainfall, temperature, dates):
    """Convenience function for running catchmod

    Parameters
    C : pycatchmod.OudinCatchment
    rainfall : numpy.array
    pet : numpy.array
    """
    import numpy as np

    C.reset()

    # number of scenarios
    N = C.subcatchments[0].soil_store.initial_upper_deficit.shape[0]
    assert(rainfall.shape[1] == N)

    # input timesteps
    M = rainfall.shape[0]
    # output timesteps
    if dates is not None:
        M2 = len(dates)
    else:
        M2 = M

    perc = np.zeros((len(C.subcatchments), N))
    outflow = np.zeros_like(perc)
    total_outflow = np.zeros(M)
    pet = np.zeros(N)
    flow = np.zeros([M2, N])
    flows = np.zeros([M2, len(C.subcatchments)])

    # TODO: add option to enable/disable extra leap days

    i = 0
    for j in range(M2):
        date = dates[j]
        if M != M2:
            if date.month == 2 and date.day == 29:
                # input data is missing leap days, use previous day
                i -= 1

        r = rainfall[i, ...].reshape(N).astype(np.float64)
        t = temperature[i, ...].reshape(N).astype(np.float64)

        C.step(date.dayofyear, r, t, pet, perc, outflow)

        flows[j, ...] = outflow[:, 0]
        flow[j, ...] = outflow.sum(axis=0).reshape(rainfall.shape[1:])

        i += 1

    return flow

# %%
plot = False
max_scenarios_to_process = None  # process all scenarios

# Change thise to run different sub-samples
sample_sizes = (10, 25, 50, 100, 200)
for ss in sample_sizes:
    print(f'Starting flow generation for sub-sample of size {ss}.')
    WEATHER = os.path.join(DATA_DIR, f'ukcp09_sub{ss:03d}.h5')
    FLOWS = os.path.join(DATA_DIR, f'catchmod_flows_sub{ss:03d}.h5')
    FLOWS_BY_CATCHMENT = os.path.join(DATA_DIR, f'catchmod_flows_by_catchment_sub{ss:03d}.h5')

    with pandas.HDFStore(WEATHER, mode='r') as store, \
        pandas.HDFStore(FLOWS, mode='w', complib='zlib', complevel=9) as out_store:

            i = 0
            for key in store.keys():
                if 'hly' in key:
                    continue  # Skip hourly data

                print('Predicting flow for scenario: "{}"'.format(key))
                df = store[key]

                # Massage the dates into a timeseries index.
                # NOTE: UKCP09 uses notional years starting in 3000.
                # pandas doesn't like dates this far in the future say we move them to 2000
                dates = {k: df.index.get_level_values(k) for k in ('year', 'month', 'day')}
                dates['year'] = dates['year'] - 1000
                dates = pandas.to_datetime(dates)

                rainfall = df['precip_dtotal'].values[:, np.newaxis]
                pet = df['pet_dmean'].values[:, np.newaxis]

                flows = {}
                for i, model in enumerate(models):
                    flow = run_catchmod(model, rainfall, pet, dates)
                    flow /= 1e3  # Convert to Mm3/day
                    flows[model.name] = flow[:, 0]

                flows = pandas.DataFrame(data=flows, index=dates)
                flows.name = key
                out_store[key] = flows

                if plot:
                    for ax, model in zip(axarr, models):
                        flows[model.name].plot(ax=ax)
                        flows[model.name].resample('M').mean().plot(ax=ax)
                        flows[model.name].resample('A').mean().plot(ax=ax, style='-o')

                i += 1
                if max_scenarios_to_process is not None and i >= max_scenarios_to_process:
                    break
# Out:
# Starting flow generation for sub-sample of size 10.
# Predicting flow for scenario: "/r_0062_cntr_dly"
# Predicting flow for scenario: "/r_0062_scen_dly"
# Predicting flow for scenario: "/r_0136_cntr_dly"
# Predicting flow for scenario: "/r_0136_scen_dly"
# Predicting flow for scenario: "/r_0272_cntr_dly"
# Predicting flow for scenario: "/r_0272_scen_dly"
# Predicting flow for scenario: "/r_0321_cntr_dly"
# Predicting flow for scenario: "/r_0321_scen_dly"
# Predicting flow for scenario: "/r_0498_cntr_dly"
# Predicting flow for scenario: "/r_0498_scen_dly"
# Predicting flow for scenario: "/r_0586_cntr_dly"
# Predicting flow for scenario: "/r_0586_scen_dly"
# Predicting flow for scenario: "/r_0604_cntr_dly"
# Predicting flow for scenario: "/r_0604_scen_dly"
# Predicting flow for scenario: "/r_0636_cntr_dly"
# Predicting flow for scenario: "/r_0636_scen_dly"
# Predicting flow for scenario: "/r_0697_cntr_dly"
# Predicting flow for scenario: "/r_0697_scen_dly"
# Predicting flow for scenario: "/r_0799_cntr_dly"
# Predicting flow for scenario: "/r_0799_scen_dly"
# Starting flow generation for sub-sample of size 25.
# Predicting flow for scenario: "/r_0027_cntr_dly"
# Predicting flow for scenario: "/r_0027_scen_dly"
# Predicting flow for scenario: "/r_0034_cntr_dly"
# Predicting flow for scenario: "/r_0034_scen_dly"
# Predicting flow for scenario: "/r_0037_cntr_dly"
# Predicting flow for scenario: "/r_0037_scen_dly"
# Predicting flow for scenario: "/r_0057_cntr_dly"
# Predicting flow for scenario: "/r_0057_scen_dly"
# Predicting flow for scenario: "/r_0081_cntr_dly"
# Predicting flow for scenario: "/r_0081_scen_dly"
# Predicting flow for scenario: "/r_0123_cntr_dly"
# Predicting flow for scenario: "/r_0123_scen_dly"
# Predicting flow for scenario: "/r_0131_cntr_dly"
# Predicting flow for scenario: "/r_0131_scen_dly"
# Predicting flow for scenario: "/r_0136_cntr_dly"
# Predicting flow for scenario: "/r_0136_scen_dly"
# Predicting flow for scenario: "/r_0157_cntr_dly"
# Predicting flow for scenario: "/r_0157_scen_dly"
# Predicting flow for scenario: "/r_0323_cntr_dly"
# Predicting flow for scenario: "/r_0323_scen_dly"
# Predicting flow for scenario: "/r_0365_cntr_dly"
# Predicting flow for scenario: "/r_0365_scen_dly"
# Predicting flow for scenario: "/r_0384_cntr_dly"
# Predicting flow for scenario: "/r_0384_scen_dly"
# Predicting flow for scenario: "/r_0492_cntr_dly"
# Predicting flow for scenario: "/r_0492_scen_dly"
# Predicting flow for scenario: "/r_0518_cntr_dly"
# Predicting flow for scenario: "/r_0518_scen_dly"
# Predicting flow for scenario: "/r_0548_cntr_dly"
# Predicting flow for scenario: "/r_0548_scen_dly"
# Predicting flow for scenario: "/r_0590_cntr_dly"
# Predicting flow for scenario: "/r_0590_scen_dly"
# Predicting flow for scenario: "/r_0649_cntr_dly"
# Predicting flow for scenario: "/r_0649_scen_dly"
# Predicting flow for scenario: "/r_0674_cntr_dly"
# Predicting flow for scenario: "/r_0674_scen_dly"
# Predicting flow for scenario: "/r_0793_cntr_dly"
# Predicting flow for scenario: "/r_0793_scen_dly"
# Predicting flow for scenario: "/r_0861_cntr_dly"
# Predicting flow for scenario: "/r_0861_scen_dly"
# Predicting flow for scenario: "/r_0907_cntr_dly"
# Predicting flow for scenario: "/r_0907_scen_dly"
# Predicting flow for scenario: "/r_0916_cntr_dly"
# Predicting flow for scenario: "/r_0916_scen_dly"
# Predicting flow for scenario: "/r_0956_cntr_dly"
# Predicting flow for scenario: "/r_0956_scen_dly"
# Predicting flow for scenario: "/r_0989_cntr_dly"
# Predicting flow for scenario: "/r_0989_scen_dly"
# Predicting flow for scenario: "/r_0995_cntr_dly"
# Predicting flow for scenario: "/r_0995_scen_dly"
# Starting flow generation for sub-sample of size 50.
# Predicting flow for scenario: "/r_0008_cntr_dly"
# Predicting flow for scenario: "/r_0008_scen_dly"
# Predicting flow for scenario: "/r_0011_cntr_dly"
# Predicting flow for scenario: "/r_0011_scen_dly"
# Predicting flow for scenario: "/r_0030_cntr_dly"
# Predicting flow for scenario: "/r_0030_scen_dly"
# Predicting flow for scenario: "/r_0033_cntr_dly"
# Predicting flow for scenario: "/r_0033_scen_dly"
# Predicting flow for scenario: "/r_0044_cntr_dly"
# Predicting flow for scenario: "/r_0044_scen_dly"
# Predicting flow for scenario: "/r_0069_cntr_dly"
# Predicting flow for scenario: "/r_0069_scen_dly"
# Predicting flow for scenario: "/r_0094_cntr_dly"
# Predicting flow for scenario: "/r_0094_scen_dly"
# Predicting flow for scenario: "/r_0108_cntr_dly"
# Predicting flow for scenario: "/r_0108_scen_dly"
# Predicting flow for scenario: "/r_0121_cntr_dly"
# Predicting flow for scenario: "/r_0121_scen_dly"
# Predicting flow for scenario: "/r_0135_cntr_dly"
# Predicting flow for scenario: "/r_0135_scen_dly"
# Predicting flow for scenario: "/r_0163_cntr_dly"
# Predicting flow for scenario: "/r_0163_scen_dly"
# Predicting flow for scenario: "/r_0189_cntr_dly"
# Predicting flow for scenario: "/r_0189_scen_dly"
# Predicting flow for scenario: "/r_0242_cntr_dly"
# Predicting flow for scenario: "/r_0242_scen_dly"
# Predicting flow for scenario: "/r_0263_cntr_dly"
# Predicting flow for scenario: "/r_0263_scen_dly"
# Predicting flow for scenario: "/r_0267_cntr_dly"
# Predicting flow for scenario: "/r_0267_scen_dly"
# Predicting flow for scenario: "/r_0274_cntr_dly"
# Predicting flow for scenario: "/r_0274_scen_dly"
# Predicting flow for scenario: "/r_0275_cntr_dly"
# Predicting flow for scenario: "/r_0275_scen_dly"
# Predicting flow for scenario: "/r_0345_cntr_dly"
# Predicting flow for scenario: "/r_0345_scen_dly"
# Predicting flow for scenario: "/r_0350_cntr_dly"
# Predicting flow for scenario: "/r_0350_scen_dly"
# Predicting flow for scenario: "/r_0361_cntr_dly"
# Predicting flow for scenario: "/r_0361_scen_dly"
# Predicting flow for scenario: "/r_0377_cntr_dly"
# Predicting flow for scenario: "/r_0377_scen_dly"
# Predicting flow for scenario: "/r_0417_cntr_dly"
# Predicting flow for scenario: "/r_0417_scen_dly"
# Predicting flow for scenario: "/r_0441_cntr_dly"
# Predicting flow for scenario: "/r_0441_scen_dly"
# Predicting flow for scenario: "/r_0450_cntr_dly"
# Predicting flow for scenario: "/r_0450_scen_dly"
# Predicting flow for scenario: "/r_0467_cntr_dly"
# Predicting flow for scenario: "/r_0467_scen_dly"
# Predicting flow for scenario: "/r_0471_cntr_dly"
# Predicting flow for scenario: "/r_0471_scen_dly"
# Predicting flow for scenario: "/r_0478_cntr_dly"
# Predicting flow for scenario: "/r_0478_scen_dly"
# Predicting flow for scenario: "/r_0486_cntr_dly"
# Predicting flow for scenario: "/r_0486_scen_dly"
# Predicting flow for scenario: "/r_0487_cntr_dly"
# Predicting flow for scenario: "/r_0487_scen_dly"
# Predicting flow for scenario: "/r_0581_cntr_dly"
# Predicting flow for scenario: "/r_0581_scen_dly"
# Predicting flow for scenario: "/r_0583_cntr_dly"
# Predicting flow for scenario: "/r_0583_scen_dly"
# Predicting flow for scenario: "/r_0589_cntr_dly"
# Predicting flow for scenario: "/r_0589_scen_dly"
# Predicting flow for scenario: "/r_0654_cntr_dly"
# Predicting flow for scenario: "/r_0654_scen_dly"
# Predicting flow for scenario: "/r_0663_cntr_dly"
# Predicting flow for scenario: "/r_0663_scen_dly"
# Predicting flow for scenario: "/r_0667_cntr_dly"
# Predicting flow for scenario: "/r_0667_scen_dly"
# Predicting flow for scenario: "/r_0694_cntr_dly"
# Predicting flow for scenario: "/r_0694_scen_dly"
# Predicting flow for scenario: "/r_0695_cntr_dly"
# Predicting flow for scenario: "/r_0695_scen_dly"
# Predicting flow for scenario: "/r_0698_cntr_dly"
# Predicting flow for scenario: "/r_0698_scen_dly"
# Predicting flow for scenario: "/r_0728_cntr_dly"
# Predicting flow for scenario: "/r_0728_scen_dly"
# Predicting flow for scenario: "/r_0738_cntr_dly"
# Predicting flow for scenario: "/r_0738_scen_dly"
# Predicting flow for scenario: "/r_0781_cntr_dly"
# Predicting flow for scenario: "/r_0781_scen_dly"
# Predicting flow for scenario: "/r_0802_cntr_dly"
# Predicting flow for scenario: "/r_0802_scen_dly"
# Predicting flow for scenario: "/r_0846_cntr_dly"
# Predicting flow for scenario: "/r_0846_scen_dly"
# Predicting flow for scenario: "/r_0852_cntr_dly"
# Predicting flow for scenario: "/r_0852_scen_dly"
# Predicting flow for scenario: "/r_0855_cntr_dly"
# Predicting flow for scenario: "/r_0855_scen_dly"
# Predicting flow for scenario: "/r_0868_cntr_dly"
# Predicting flow for scenario: "/r_0868_scen_dly"
# Predicting flow for scenario: "/r_0923_cntr_dly"
# Predicting flow for scenario: "/r_0923_scen_dly"
# Predicting flow for scenario: "/r_0947_cntr_dly"
# Predicting flow for scenario: "/r_0947_scen_dly"
# Predicting flow for scenario: "/r_0977_cntr_dly"
# Predicting flow for scenario: "/r_0977_scen_dly"
# Predicting flow for scenario: "/r_0986_cntr_dly"
# Predicting flow for scenario: "/r_0986_scen_dly"
# Starting flow generation for sub-sample of size 100.
# Predicting flow for scenario: "/r_0008_cntr_dly"
# Predicting flow for scenario: "/r_0008_scen_dly"
# Predicting flow for scenario: "/r_0023_cntr_dly"
# Predicting flow for scenario: "/r_0023_scen_dly"
# Predicting flow for scenario: "/r_0028_cntr_dly"
# Predicting flow for scenario: "/r_0028_scen_dly"
# Predicting flow for scenario: "/r_0029_cntr_dly"
# Predicting flow for scenario: "/r_0029_scen_dly"
# Predicting flow for scenario: "/r_0030_cntr_dly"
# Predicting flow for scenario: "/r_0030_scen_dly"
# Predicting flow for scenario: "/r_0038_cntr_dly"
# Predicting flow for scenario: "/r_0038_scen_dly"
# Predicting flow for scenario: "/r_0043_cntr_dly"
# Predicting flow for scenario: "/r_0043_scen_dly"
# Predicting flow for scenario: "/r_0044_cntr_dly"
# Predicting flow for scenario: "/r_0044_scen_dly"
# Predicting flow for scenario: "/r_0049_cntr_dly"
# Predicting flow for scenario: "/r_0049_scen_dly"
# Predicting flow for scenario: "/r_0060_cntr_dly"
# Predicting flow for scenario: "/r_0060_scen_dly"
# Predicting flow for scenario: "/r_0067_cntr_dly"
# Predicting flow for scenario: "/r_0067_scen_dly"
# Predicting flow for scenario: "/r_0068_cntr_dly"
# Predicting flow for scenario: "/r_0068_scen_dly"
# Predicting flow for scenario: "/r_0087_cntr_dly"
# Predicting flow for scenario: "/r_0087_scen_dly"
# Predicting flow for scenario: "/r_0089_cntr_dly"
# Predicting flow for scenario: "/r_0089_scen_dly"
# Predicting flow for scenario: "/r_0094_cntr_dly"
# Predicting flow for scenario: "/r_0094_scen_dly"
# Predicting flow for scenario: "/r_0096_cntr_dly"
# Predicting flow for scenario: "/r_0096_scen_dly"
# Predicting flow for scenario: "/r_0104_cntr_dly"
# Predicting flow for scenario: "/r_0104_scen_dly"
# Predicting flow for scenario: "/r_0110_cntr_dly"
# Predicting flow for scenario: "/r_0110_scen_dly"
# Predicting flow for scenario: "/r_0134_cntr_dly"
# Predicting flow for scenario: "/r_0134_scen_dly"
# Predicting flow for scenario: "/r_0165_cntr_dly"
# Predicting flow for scenario: "/r_0165_scen_dly"
# Predicting flow for scenario: "/r_0181_cntr_dly"
# Predicting flow for scenario: "/r_0181_scen_dly"
# Predicting flow for scenario: "/r_0185_cntr_dly"
# Predicting flow for scenario: "/r_0185_scen_dly"
# Predicting flow for scenario: "/r_0218_cntr_dly"
# Predicting flow for scenario: "/r_0218_scen_dly"
# Predicting flow for scenario: "/r_0220_cntr_dly"
# Predicting flow for scenario: "/r_0220_scen_dly"
# Predicting flow for scenario: "/r_0237_cntr_dly"
# Predicting flow for scenario: "/r_0237_scen_dly"
# Predicting flow for scenario: "/r_0265_cntr_dly"
# Predicting flow for scenario: "/r_0265_scen_dly"
# Predicting flow for scenario: "/r_0268_cntr_dly"
# Predicting flow for scenario: "/r_0268_scen_dly"
# Predicting flow for scenario: "/r_0277_cntr_dly"
# Predicting flow for scenario: "/r_0277_scen_dly"
# Predicting flow for scenario: "/r_0311_cntr_dly"
# Predicting flow for scenario: "/r_0311_scen_dly"
# Predicting flow for scenario: "/r_0321_cntr_dly"
# Predicting flow for scenario: "/r_0321_scen_dly"
# Predicting flow for scenario: "/r_0324_cntr_dly"
# Predicting flow for scenario: "/r_0324_scen_dly"
# Predicting flow for scenario: "/r_0327_cntr_dly"
# Predicting flow for scenario: "/r_0327_scen_dly"
# Predicting flow for scenario: "/r_0344_cntr_dly"
# Predicting flow for scenario: "/r_0344_scen_dly"
# Predicting flow for scenario: "/r_0355_cntr_dly"
# Predicting flow for scenario: "/r_0355_scen_dly"
# Predicting flow for scenario: "/r_0371_cntr_dly"
# Predicting flow for scenario: "/r_0371_scen_dly"
# Predicting flow for scenario: "/r_0380_cntr_dly"
# Predicting flow for scenario: "/r_0380_scen_dly"
# Predicting flow for scenario: "/r_0381_cntr_dly"
# Predicting flow for scenario: "/r_0381_scen_dly"
# Predicting flow for scenario: "/r_0397_cntr_dly"
# Predicting flow for scenario: "/r_0397_scen_dly"
# Predicting flow for scenario: "/r_0419_cntr_dly"
# Predicting flow for scenario: "/r_0419_scen_dly"
# Predicting flow for scenario: "/r_0424_cntr_dly"
# Predicting flow for scenario: "/r_0424_scen_dly"
# Predicting flow for scenario: "/r_0428_cntr_dly"
# Predicting flow for scenario: "/r_0428_scen_dly"
# Predicting flow for scenario: "/r_0429_cntr_dly"
# Predicting flow for scenario: "/r_0429_scen_dly"
# Predicting flow for scenario: "/r_0439_cntr_dly"
# Predicting flow for scenario: "/r_0439_scen_dly"
# Predicting flow for scenario: "/r_0445_cntr_dly"
# Predicting flow for scenario: "/r_0445_scen_dly"
# Predicting flow for scenario: "/r_0450_cntr_dly"
# Predicting flow for scenario: "/r_0450_scen_dly"
# Predicting flow for scenario: "/r_0459_cntr_dly"
# Predicting flow for scenario: "/r_0459_scen_dly"
# Predicting flow for scenario: "/r_0486_cntr_dly"
# Predicting flow for scenario: "/r_0486_scen_dly"
# Predicting flow for scenario: "/r_0516_cntr_dly"
# Predicting flow for scenario: "/r_0516_scen_dly"
# Predicting flow for scenario: "/r_0518_cntr_dly"
# Predicting flow for scenario: "/r_0518_scen_dly"
# Predicting flow for scenario: "/r_0521_cntr_dly"
# Predicting flow for scenario: "/r_0521_scen_dly"
# Predicting flow for scenario: "/r_0523_cntr_dly"
# Predicting flow for scenario: "/r_0523_scen_dly"
# Predicting flow for scenario: "/r_0530_cntr_dly"
# Predicting flow for scenario: "/r_0530_scen_dly"
# Predicting flow for scenario: "/r_0548_cntr_dly"
# Predicting flow for scenario: "/r_0548_scen_dly"
# Predicting flow for scenario: "/r_0555_cntr_dly"
# Predicting flow for scenario: "/r_0555_scen_dly"
# Predicting flow for scenario: "/r_0572_cntr_dly"
# Predicting flow for scenario: "/r_0572_scen_dly"
# Predicting flow for scenario: "/r_0578_cntr_dly"
# Predicting flow for scenario: "/r_0578_scen_dly"
# Predicting flow for scenario: "/r_0599_cntr_dly"
# Predicting flow for scenario: "/r_0599_scen_dly"
# Predicting flow for scenario: "/r_0600_cntr_dly"
# Predicting flow for scenario: "/r_0600_scen_dly"
# Predicting flow for scenario: "/r_0601_cntr_dly"
# Predicting flow for scenario: "/r_0601_scen_dly"
# Predicting flow for scenario: "/r_0612_cntr_dly"
# Predicting flow for scenario: "/r_0612_scen_dly"
# Predicting flow for scenario: "/r_0617_cntr_dly"
# Predicting flow for scenario: "/r_0617_scen_dly"
# Predicting flow for scenario: "/r_0663_cntr_dly"
# Predicting flow for scenario: "/r_0663_scen_dly"
# Predicting flow for scenario: "/r_0678_cntr_dly"
# Predicting flow for scenario: "/r_0678_scen_dly"
# Predicting flow for scenario: "/r_0685_cntr_dly"
# Predicting flow for scenario: "/r_0685_scen_dly"
# Predicting flow for scenario: "/r_0698_cntr_dly"
# Predicting flow for scenario: "/r_0698_scen_dly"
# Predicting flow for scenario: "/r_0700_cntr_dly"
# Predicting flow for scenario: "/r_0700_scen_dly"
# Predicting flow for scenario: "/r_0703_cntr_dly"
# Predicting flow for scenario: "/r_0703_scen_dly"
# Predicting flow for scenario: "/r_0713_cntr_dly"
# Predicting flow for scenario: "/r_0713_scen_dly"
# Predicting flow for scenario: "/r_0729_cntr_dly"
# Predicting flow for scenario: "/r_0729_scen_dly"
# Predicting flow for scenario: "/r_0749_cntr_dly"
# Predicting flow for scenario: "/r_0749_scen_dly"
# Predicting flow for scenario: "/r_0771_cntr_dly"
# Predicting flow for scenario: "/r_0771_scen_dly"
# Predicting flow for scenario: "/r_0772_cntr_dly"
# Predicting flow for scenario: "/r_0772_scen_dly"
# Predicting flow for scenario: "/r_0777_cntr_dly"
# Predicting flow for scenario: "/r_0777_scen_dly"
# Predicting flow for scenario: "/r_0782_cntr_dly"
# Predicting flow for scenario: "/r_0782_scen_dly"
# Predicting flow for scenario: "/r_0784_cntr_dly"
# Predicting flow for scenario: "/r_0784_scen_dly"
# Predicting flow for scenario: "/r_0795_cntr_dly"
# Predicting flow for scenario: "/r_0795_scen_dly"
# Predicting flow for scenario: "/r_0802_cntr_dly"
# Predicting flow for scenario: "/r_0802_scen_dly"
# Predicting flow for scenario: "/r_0804_cntr_dly"
# Predicting flow for scenario: "/r_0804_scen_dly"
# Predicting flow for scenario: "/r_0815_cntr_dly"
# Predicting flow for scenario: "/r_0815_scen_dly"
# Predicting flow for scenario: "/r_0824_cntr_dly"
# Predicting flow for scenario: "/r_0824_scen_dly"
# Predicting flow for scenario: "/r_0825_cntr_dly"
# Predicting flow for scenario: "/r_0825_scen_dly"
# Predicting flow for scenario: "/r_0829_cntr_dly"
# Predicting flow for scenario: "/r_0829_scen_dly"
# Predicting flow for scenario: "/r_0852_cntr_dly"
# Predicting flow for scenario: "/r_0852_scen_dly"
# Predicting flow for scenario: "/r_0872_cntr_dly"
# Predicting flow for scenario: "/r_0872_scen_dly"
# Predicting flow for scenario: "/r_0881_cntr_dly"
# Predicting flow for scenario: "/r_0881_scen_dly"
# Predicting flow for scenario: "/r_0900_cntr_dly"
# Predicting flow for scenario: "/r_0900_scen_dly"
# Predicting flow for scenario: "/r_0903_cntr_dly"
# Predicting flow for scenario: "/r_0903_scen_dly"
# Predicting flow for scenario: "/r_0910_cntr_dly"
# Predicting flow for scenario: "/r_0910_scen_dly"
# Predicting flow for scenario: "/r_0926_cntr_dly"
# Predicting flow for scenario: "/r_0926_scen_dly"
# Predicting flow for scenario: "/r_0928_cntr_dly"
# Predicting flow for scenario: "/r_0928_scen_dly"
# Predicting flow for scenario: "/r_0948_cntr_dly"
# Predicting flow for scenario: "/r_0948_scen_dly"
# Predicting flow for scenario: "/r_0962_cntr_dly"
# Predicting flow for scenario: "/r_0962_scen_dly"
# Predicting flow for scenario: "/r_0966_cntr_dly"
# Predicting flow for scenario: "/r_0966_scen_dly"
# Predicting flow for scenario: "/r_0977_cntr_dly"
# Predicting flow for scenario: "/r_0977_scen_dly"
# Predicting flow for scenario: "/r_0980_cntr_dly"
# Predicting flow for scenario: "/r_0980_scen_dly"
# Predicting flow for scenario: "/r_0987_cntr_dly"
# Predicting flow for scenario: "/r_0987_scen_dly"
# Predicting flow for scenario: "/r_0994_cntr_dly"
# Predicting flow for scenario: "/r_0994_scen_dly"
# Predicting flow for scenario: "/r_0995_cntr_dly"
# Predicting flow for scenario: "/r_0995_scen_dly"
# Predicting flow for scenario: "/r_1000_cntr_dly"
# Predicting flow for scenario: "/r_1000_scen_dly"
# Starting flow generation for sub-sample of size 200.
# Predicting flow for scenario: "/r_0015_cntr_dly"
# Predicting flow for scenario: "/r_0015_scen_dly"
# Predicting flow for scenario: "/r_0016_cntr_dly"
# Predicting flow for scenario: "/r_0016_scen_dly"
# Predicting flow for scenario: "/r_0026_cntr_dly"
# Predicting flow for scenario: "/r_0026_scen_dly"
# Predicting flow for scenario: "/r_0032_cntr_dly"
# Predicting flow for scenario: "/r_0032_scen_dly"
# Predicting flow for scenario: "/r_0033_cntr_dly"
# Predicting flow for scenario: "/r_0033_scen_dly"
# Predicting flow for scenario: "/r_0044_cntr_dly"
# Predicting flow for scenario: "/r_0044_scen_dly"
# Predicting flow for scenario: "/r_0049_cntr_dly"
# Predicting flow for scenario: "/r_0049_scen_dly"
# Predicting flow for scenario: "/r_0051_cntr_dly"
# Predicting flow for scenario: "/r_0051_scen_dly"
# Predicting flow for scenario: "/r_0054_cntr_dly"
# Predicting flow for scenario: "/r_0054_scen_dly"
# Predicting flow for scenario: "/r_0063_cntr_dly"
# Predicting flow for scenario: "/r_0063_scen_dly"
# Predicting flow for scenario: "/r_0064_cntr_dly"
# Predicting flow for scenario: "/r_0064_scen_dly"
# Predicting flow for scenario: "/r_0074_cntr_dly"
# Predicting flow for scenario: "/r_0074_scen_dly"
# Predicting flow for scenario: "/r_0076_cntr_dly"
# Predicting flow for scenario: "/r_0076_scen_dly"
# Predicting flow for scenario: "/r_0078_cntr_dly"
# Predicting flow for scenario: "/r_0078_scen_dly"
# Predicting flow for scenario: "/r_0090_cntr_dly"
# Predicting flow for scenario: "/r_0090_scen_dly"
# Predicting flow for scenario: "/r_0091_cntr_dly"
# Predicting flow for scenario: "/r_0091_scen_dly"
# Predicting flow for scenario: "/r_0106_cntr_dly"
# Predicting flow for scenario: "/r_0106_scen_dly"
# Predicting flow for scenario: "/r_0110_cntr_dly"
# Predicting flow for scenario: "/r_0110_scen_dly"
# Predicting flow for scenario: "/r_0114_cntr_dly"
# Predicting flow for scenario: "/r_0114_scen_dly"
# Predicting flow for scenario: "/r_0116_cntr_dly"
# Predicting flow for scenario: "/r_0116_scen_dly"
# Predicting flow for scenario: "/r_0119_cntr_dly"
# Predicting flow for scenario: "/r_0119_scen_dly"
# Predicting flow for scenario: "/r_0125_cntr_dly"
# Predicting flow for scenario: "/r_0125_scen_dly"
# Predicting flow for scenario: "/r_0126_cntr_dly"
# Predicting flow for scenario: "/r_0126_scen_dly"
# Predicting flow for scenario: "/r_0128_cntr_dly"
# Predicting flow for scenario: "/r_0128_scen_dly"
# Predicting flow for scenario: "/r_0129_cntr_dly"
# Predicting flow for scenario: "/r_0129_scen_dly"
# Predicting flow for scenario: "/r_0133_cntr_dly"
# Predicting flow for scenario: "/r_0133_scen_dly"
# Predicting flow for scenario: "/r_0136_cntr_dly"
# Predicting flow for scenario: "/r_0136_scen_dly"
# Predicting flow for scenario: "/r_0141_cntr_dly"
# Predicting flow for scenario: "/r_0141_scen_dly"
# Predicting flow for scenario: "/r_0143_cntr_dly"
# Predicting flow for scenario: "/r_0143_scen_dly"
# Predicting flow for scenario: "/r_0147_cntr_dly"
# Predicting flow for scenario: "/r_0147_scen_dly"
# Predicting flow for scenario: "/r_0149_cntr_dly"
# Predicting flow for scenario: "/r_0149_scen_dly"
# Predicting flow for scenario: "/r_0154_cntr_dly"
# Predicting flow for scenario: "/r_0154_scen_dly"
# Predicting flow for scenario: "/r_0156_cntr_dly"
# Predicting flow for scenario: "/r_0156_scen_dly"
# Predicting flow for scenario: "/r_0170_cntr_dly"
# Predicting flow for scenario: "/r_0170_scen_dly"
# Predicting flow for scenario: "/r_0174_cntr_dly"
# Predicting flow for scenario: "/r_0174_scen_dly"
# Predicting flow for scenario: "/r_0179_cntr_dly"
# Predicting flow for scenario: "/r_0179_scen_dly"
# Predicting flow for scenario: "/r_0181_cntr_dly"
# Predicting flow for scenario: "/r_0181_scen_dly"
# Predicting flow for scenario: "/r_0183_cntr_dly"
# Predicting flow for scenario: "/r_0183_scen_dly"
# Predicting flow for scenario: "/r_0187_cntr_dly"
# Predicting flow for scenario: "/r_0187_scen_dly"
# Predicting flow for scenario: "/r_0190_cntr_dly"
# Predicting flow for scenario: "/r_0190_scen_dly"
# Predicting flow for scenario: "/r_0191_cntr_dly"
# Predicting flow for scenario: "/r_0191_scen_dly"
# Predicting flow for scenario: "/r_0199_cntr_dly"
# Predicting flow for scenario: "/r_0199_scen_dly"
# Predicting flow for scenario: "/r_0204_cntr_dly"
# Predicting flow for scenario: "/r_0204_scen_dly"
# Predicting flow for scenario: "/r_0206_cntr_dly"
# Predicting flow for scenario: "/r_0206_scen_dly"
# Predicting flow for scenario: "/r_0208_cntr_dly"
# Predicting flow for scenario: "/r_0208_scen_dly"
# Predicting flow for scenario: "/r_0209_cntr_dly"
# Predicting flow for scenario: "/r_0209_scen_dly"
# Predicting flow for scenario: "/r_0214_cntr_dly"
# Predicting flow for scenario: "/r_0214_scen_dly"
# Predicting flow for scenario: "/r_0215_cntr_dly"
# Predicting flow for scenario: "/r_0215_scen_dly"
# Predicting flow for scenario: "/r_0216_cntr_dly"
# Predicting flow for scenario: "/r_0216_scen_dly"
# Predicting flow for scenario: "/r_0219_cntr_dly"
# Predicting flow for scenario: "/r_0219_scen_dly"
# Predicting flow for scenario: "/r_0228_cntr_dly"
# Predicting flow for scenario: "/r_0228_scen_dly"
# Predicting flow for scenario: "/r_0233_cntr_dly"
# Predicting flow for scenario: "/r_0233_scen_dly"
# Predicting flow for scenario: "/r_0244_cntr_dly"
# Predicting flow for scenario: "/r_0244_scen_dly"
# Predicting flow for scenario: "/r_0245_cntr_dly"
# Predicting flow for scenario: "/r_0245_scen_dly"
# Predicting flow for scenario: "/r_0250_cntr_dly"
# Predicting flow for scenario: "/r_0250_scen_dly"
# Predicting flow for scenario: "/r_0257_cntr_dly"
# Predicting flow for scenario: "/r_0257_scen_dly"
# Predicting flow for scenario: "/r_0259_cntr_dly"
# Predicting flow for scenario: "/r_0259_scen_dly"
# Predicting flow for scenario: "/r_0269_cntr_dly"
# Predicting flow for scenario: "/r_0269_scen_dly"
# Predicting flow for scenario: "/r_0271_cntr_dly"
# Predicting flow for scenario: "/r_0271_scen_dly"
# Predicting flow for scenario: "/r_0272_cntr_dly"
# Predicting flow for scenario: "/r_0272_scen_dly"
# Predicting flow for scenario: "/r_0274_cntr_dly"
# Predicting flow for scenario: "/r_0274_scen_dly"
# Predicting flow for scenario: "/r_0276_cntr_dly"
# Predicting flow for scenario: "/r_0276_scen_dly"
# Predicting flow for scenario: "/r_0281_cntr_dly"
# Predicting flow for scenario: "/r_0281_scen_dly"
# Predicting flow for scenario: "/r_0282_cntr_dly"
# Predicting flow for scenario: "/r_0282_scen_dly"
# Predicting flow for scenario: "/r_0287_cntr_dly"
# Predicting flow for scenario: "/r_0287_scen_dly"
# Predicting flow for scenario: "/r_0293_cntr_dly"
# Predicting flow for scenario: "/r_0293_scen_dly"
# Predicting flow for scenario: "/r_0295_cntr_dly"
# Predicting flow for scenario: "/r_0295_scen_dly"
# Predicting flow for scenario: "/r_0298_cntr_dly"
# Predicting flow for scenario: "/r_0298_scen_dly"
# Predicting flow for scenario: "/r_0299_cntr_dly"
# Predicting flow for scenario: "/r_0299_scen_dly"
# Predicting flow for scenario: "/r_0302_cntr_dly"
# Predicting flow for scenario: "/r_0302_scen_dly"
# Predicting flow for scenario: "/r_0306_cntr_dly"
# Predicting flow for scenario: "/r_0306_scen_dly"
# Predicting flow for scenario: "/r_0313_cntr_dly"
# Predicting flow for scenario: "/r_0313_scen_dly"
# Predicting flow for scenario: "/r_0315_cntr_dly"
# Predicting flow for scenario: "/r_0315_scen_dly"
# Predicting flow for scenario: "/r_0335_cntr_dly"
# Predicting flow for scenario: "/r_0335_scen_dly"
# Predicting flow for scenario: "/r_0340_cntr_dly"
# Predicting flow for scenario: "/r_0340_scen_dly"
# Predicting flow for scenario: "/r_0343_cntr_dly"
# Predicting flow for scenario: "/r_0343_scen_dly"
# Predicting flow for scenario: "/r_0356_cntr_dly"
# Predicting flow for scenario: "/r_0356_scen_dly"
# Predicting flow for scenario: "/r_0360_cntr_dly"
# Predicting flow for scenario: "/r_0360_scen_dly"
# Predicting flow for scenario: "/r_0381_cntr_dly"
# Predicting flow for scenario: "/r_0381_scen_dly"
# Predicting flow for scenario: "/r_0382_cntr_dly"
# Predicting flow for scenario: "/r_0382_scen_dly"
# Predicting flow for scenario: "/r_0386_cntr_dly"
# Predicting flow for scenario: "/r_0386_scen_dly"
# Predicting flow for scenario: "/r_0388_cntr_dly"
# Predicting flow for scenario: "/r_0388_scen_dly"
# Predicting flow for scenario: "/r_0389_cntr_dly"
# Predicting flow for scenario: "/r_0389_scen_dly"
# Predicting flow for scenario: "/r_0395_cntr_dly"
# Predicting flow for scenario: "/r_0395_scen_dly"
# Predicting flow for scenario: "/r_0400_cntr_dly"
# Predicting flow for scenario: "/r_0400_scen_dly"
# Predicting flow for scenario: "/r_0412_cntr_dly"
# Predicting flow for scenario: "/r_0412_scen_dly"
# Predicting flow for scenario: "/r_0420_cntr_dly"
# Predicting flow for scenario: "/r_0420_scen_dly"
# Predicting flow for scenario: "/r_0428_cntr_dly"
# Predicting flow for scenario: "/r_0428_scen_dly"
# Predicting flow for scenario: "/r_0431_cntr_dly"
# Predicting flow for scenario: "/r_0431_scen_dly"
# Predicting flow for scenario: "/r_0432_cntr_dly"
# Predicting flow for scenario: "/r_0432_scen_dly"
# Predicting flow for scenario: "/r_0433_cntr_dly"
# Predicting flow for scenario: "/r_0433_scen_dly"
# Predicting flow for scenario: "/r_0446_cntr_dly"
# Predicting flow for scenario: "/r_0446_scen_dly"
# Predicting flow for scenario: "/r_0451_cntr_dly"
# Predicting flow for scenario: "/r_0451_scen_dly"
# Predicting flow for scenario: "/r_0485_cntr_dly"
# Predicting flow for scenario: "/r_0485_scen_dly"
# Predicting flow for scenario: "/r_0491_cntr_dly"
# Predicting flow for scenario: "/r_0491_scen_dly"
# Predicting flow for scenario: "/r_0492_cntr_dly"
# Predicting flow for scenario: "/r_0492_scen_dly"
# Predicting flow for scenario: "/r_0493_cntr_dly"
# Predicting flow for scenario: "/r_0493_scen_dly"
# Predicting flow for scenario: "/r_0495_cntr_dly"
# Predicting flow for scenario: "/r_0495_scen_dly"
# Predicting flow for scenario: "/r_0501_cntr_dly"
# Predicting flow for scenario: "/r_0501_scen_dly"
# Predicting flow for scenario: "/r_0505_cntr_dly"
# Predicting flow for scenario: "/r_0505_scen_dly"
# Predicting flow for scenario: "/r_0514_cntr_dly"
# Predicting flow for scenario: "/r_0514_scen_dly"
# Predicting flow for scenario: "/r_0518_cntr_dly"
# Predicting flow for scenario: "/r_0518_scen_dly"
# Predicting flow for scenario: "/r_0520_cntr_dly"
# Predicting flow for scenario: "/r_0520_scen_dly"
# Predicting flow for scenario: "/r_0523_cntr_dly"
# Predicting flow for scenario: "/r_0523_scen_dly"
# Predicting flow for scenario: "/r_0533_cntr_dly"
# Predicting flow for scenario: "/r_0533_scen_dly"
# Predicting flow for scenario: "/r_0536_cntr_dly"
# Predicting flow for scenario: "/r_0536_scen_dly"
# Predicting flow for scenario: "/r_0537_cntr_dly"
# Predicting flow for scenario: "/r_0537_scen_dly"
# Predicting flow for scenario: "/r_0547_cntr_dly"
# Predicting flow for scenario: "/r_0547_scen_dly"
# Predicting flow for scenario: "/r_0549_cntr_dly"
# Predicting flow for scenario: "/r_0549_scen_dly"
# Predicting flow for scenario: "/r_0550_cntr_dly"
# Predicting flow for scenario: "/r_0550_scen_dly"
# Predicting flow for scenario: "/r_0559_cntr_dly"
# Predicting flow for scenario: "/r_0559_scen_dly"
# Predicting flow for scenario: "/r_0561_cntr_dly"
# Predicting flow for scenario: "/r_0561_scen_dly"
# Predicting flow for scenario: "/r_0573_cntr_dly"
# Predicting flow for scenario: "/r_0573_scen_dly"
# Predicting flow for scenario: "/r_0585_cntr_dly"
# Predicting flow for scenario: "/r_0585_scen_dly"
# Predicting flow for scenario: "/r_0593_cntr_dly"
# Predicting flow for scenario: "/r_0593_scen_dly"
# Predicting flow for scenario: "/r_0594_cntr_dly"
# Predicting flow for scenario: "/r_0594_scen_dly"
# Predicting flow for scenario: "/r_0614_cntr_dly"
# Predicting flow for scenario: "/r_0614_scen_dly"
# Predicting flow for scenario: "/r_0624_cntr_dly"
# Predicting flow for scenario: "/r_0624_scen_dly"
# Predicting flow for scenario: "/r_0627_cntr_dly"
# Predicting flow for scenario: "/r_0627_scen_dly"
# Predicting flow for scenario: "/r_0639_cntr_dly"
# Predicting flow for scenario: "/r_0639_scen_dly"
# Predicting flow for scenario: "/r_0643_cntr_dly"
# Predicting flow for scenario: "/r_0643_scen_dly"
# Predicting flow for scenario: "/r_0646_cntr_dly"
# Predicting flow for scenario: "/r_0646_scen_dly"
# Predicting flow for scenario: "/r_0651_cntr_dly"
# Predicting flow for scenario: "/r_0651_scen_dly"
# Predicting flow for scenario: "/r_0653_cntr_dly"
# Predicting flow for scenario: "/r_0653_scen_dly"
# Predicting flow for scenario: "/r_0657_cntr_dly"
# Predicting flow for scenario: "/r_0657_scen_dly"
# Predicting flow for scenario: "/r_0665_cntr_dly"
# Predicting flow for scenario: "/r_0665_scen_dly"
# Predicting flow for scenario: "/r_0675_cntr_dly"
# Predicting flow for scenario: "/r_0675_scen_dly"
# Predicting flow for scenario: "/r_0684_cntr_dly"
# Predicting flow for scenario: "/r_0684_scen_dly"
# Predicting flow for scenario: "/r_0685_cntr_dly"
# Predicting flow for scenario: "/r_0685_scen_dly"
# Predicting flow for scenario: "/r_0712_cntr_dly"
# Predicting flow for scenario: "/r_0712_scen_dly"
# Predicting flow for scenario: "/r_0713_cntr_dly"
# Predicting flow for scenario: "/r_0713_scen_dly"
# Predicting flow for scenario: "/r_0729_cntr_dly"
# Predicting flow for scenario: "/r_0729_scen_dly"
# Predicting flow for scenario: "/r_0733_cntr_dly"
# Predicting flow for scenario: "/r_0733_scen_dly"
# Predicting flow for scenario: "/r_0737_cntr_dly"
# Predicting flow for scenario: "/r_0737_scen_dly"
# Predicting flow for scenario: "/r_0743_cntr_dly"
# Predicting flow for scenario: "/r_0743_scen_dly"
# Predicting flow for scenario: "/r_0747_cntr_dly"
# Predicting flow for scenario: "/r_0747_scen_dly"
# Predicting flow for scenario: "/r_0754_cntr_dly"
# Predicting flow for scenario: "/r_0754_scen_dly"
# Predicting flow for scenario: "/r_0762_cntr_dly"
# Predicting flow for scenario: "/r_0762_scen_dly"
# Predicting flow for scenario: "/r_0765_cntr_dly"
# Predicting flow for scenario: "/r_0765_scen_dly"
# Predicting flow for scenario: "/r_0767_cntr_dly"
# Predicting flow for scenario: "/r_0767_scen_dly"
# Predicting flow for scenario: "/r_0769_cntr_dly"
# Predicting flow for scenario: "/r_0769_scen_dly"
# Predicting flow for scenario: "/r_0776_cntr_dly"
# Predicting flow for scenario: "/r_0776_scen_dly"
# Predicting flow for scenario: "/r_0778_cntr_dly"
# Predicting flow for scenario: "/r_0778_scen_dly"
# Predicting flow for scenario: "/r_0780_cntr_dly"
# Predicting flow for scenario: "/r_0780_scen_dly"
# Predicting flow for scenario: "/r_0782_cntr_dly"
# Predicting flow for scenario: "/r_0782_scen_dly"
# Predicting flow for scenario: "/r_0785_cntr_dly"
# Predicting flow for scenario: "/r_0785_scen_dly"
# Predicting flow for scenario: "/r_0796_cntr_dly"
# Predicting flow for scenario: "/r_0796_scen_dly"
# Predicting flow for scenario: "/r_0808_cntr_dly"
# Predicting flow for scenario: "/r_0808_scen_dly"
# Predicting flow for scenario: "/r_0811_cntr_dly"
# Predicting flow for scenario: "/r_0811_scen_dly"
# Predicting flow for scenario: "/r_0817_cntr_dly"
# Predicting flow for scenario: "/r_0817_scen_dly"
# Predicting flow for scenario: "/r_0822_cntr_dly"
# Predicting flow for scenario: "/r_0822_scen_dly"
# Predicting flow for scenario: "/r_0823_cntr_dly"
# Predicting flow for scenario: "/r_0823_scen_dly"
# Predicting flow for scenario: "/r_0824_cntr_dly"
# Predicting flow for scenario: "/r_0824_scen_dly"
# Predicting flow for scenario: "/r_0864_cntr_dly"
# Predicting flow for scenario: "/r_0864_scen_dly"
# Predicting flow for scenario: "/r_0867_cntr_dly"
# Predicting flow for scenario: "/r_0867_scen_dly"
# Predicting flow for scenario: "/r_0872_cntr_dly"
# Predicting flow for scenario: "/r_0872_scen_dly"
# Predicting flow for scenario: "/r_0873_cntr_dly"
# Predicting flow for scenario: "/r_0873_scen_dly"
# Predicting flow for scenario: "/r_0886_cntr_dly"
# Predicting flow for scenario: "/r_0886_scen_dly"
# Predicting flow for scenario: "/r_0902_cntr_dly"
# Predicting flow for scenario: "/r_0902_scen_dly"
# Predicting flow for scenario: "/r_0903_cntr_dly"
# Predicting flow for scenario: "/r_0903_scen_dly"
# Predicting flow for scenario: "/r_0910_cntr_dly"
# Predicting flow for scenario: "/r_0910_scen_dly"
# Predicting flow for scenario: "/r_0912_cntr_dly"
# Predicting flow for scenario: "/r_0912_scen_dly"
# Predicting flow for scenario: "/r_0924_cntr_dly"
# Predicting flow for scenario: "/r_0924_scen_dly"
# Predicting flow for scenario: "/r_0928_cntr_dly"
# Predicting flow for scenario: "/r_0928_scen_dly"
# Predicting flow for scenario: "/r_0929_cntr_dly"
# Predicting flow for scenario: "/r_0929_scen_dly"
# Predicting flow for scenario: "/r_0936_cntr_dly"
# Predicting flow for scenario: "/r_0936_scen_dly"
# Predicting flow for scenario: "/r_0940_cntr_dly"
# Predicting flow for scenario: "/r_0940_scen_dly"
# Predicting flow for scenario: "/r_0941_cntr_dly"
# Predicting flow for scenario: "/r_0941_scen_dly"
# Predicting flow for scenario: "/r_0951_cntr_dly"
# Predicting flow for scenario: "/r_0951_scen_dly"
# Predicting flow for scenario: "/r_0952_cntr_dly"
# Predicting flow for scenario: "/r_0952_scen_dly"
# Predicting flow for scenario: "/r_0953_cntr_dly"
# Predicting flow for scenario: "/r_0953_scen_dly"
# Predicting flow for scenario: "/r_0955_cntr_dly"
# Predicting flow for scenario: "/r_0955_scen_dly"
# Predicting flow for scenario: "/r_0960_cntr_dly"
# Predicting flow for scenario: "/r_0960_scen_dly"
# Predicting flow for scenario: "/r_0965_cntr_dly"
# Predicting flow for scenario: "/r_0965_scen_dly"
# Predicting flow for scenario: "/r_0969_cntr_dly"
# Predicting flow for scenario: "/r_0969_scen_dly"
# Predicting flow for scenario: "/r_0984_cntr_dly"
# Predicting flow for scenario: "/r_0984_scen_dly"
# Predicting flow for scenario: "/r_0985_cntr_dly"
# Predicting flow for scenario: "/r_0985_scen_dly"
# Predicting flow for scenario: "/r_0991_cntr_dly"
# Predicting flow for scenario: "/r_0991_scen_dly"
# Predicting flow for scenario: "/r_0995_cntr_dly"
# Predicting flow for scenario: "/r_0995_scen_dly"
# Predicting flow for scenario: "/r_0997_cntr_dly"
# Predicting flow for scenario: "/r_0997_scen_dly"

# %%
for ss in sample_sizes:
    FLOWS = os.path.join(DATA_DIR, f'catchmod_flows_sub{ss:03d}.h5')
    FLOWS_BY_CATCHMENT = os.path.join(DATA_DIR, f'catchmod_flows_by_catchment_sub{ss:03d}.h5')
    
    with pandas.HDFStore(FLOWS, mode='r') as store:

            data = defaultdict(lambda: defaultdict(dict))

            i = 0
            for key in store.keys():
                if 'hly' in key:
                    continue  # Skip hourly data

                df = store[key]

                for col in df.columns:
                    if 'cntr' in key:
                        scenario = 'cntr'
                    else:
                        scenario = 'scen'    
                    data[col][scenario][key.replace("/","")] = df[col]


    with pandas.HDFStore(FLOWS_BY_CATCHMENT, mode='w', complib='zlib', complevel=9) as out_store:                

        for col in data.keys():
            for scen in data[col].keys():
                print(f'Writing combined flow for catchment-scenario: "{col}_{scen}"')
                df = pandas.concat(data[col][scen], axis=1)
                out_store[f"{col}_{scen}"] = df
# Out:
# Writing combined flow for catchment-scenario: "catchment1_cntr"
# Writing combined flow for catchment-scenario: "catchment1_scen"
# Writing combined flow for catchment-scenario: "catchment2_cntr"
# Writing combined flow for catchment-scenario: "catchment2_scen"
# Writing combined flow for catchment-scenario: "catchment3_cntr"
# Writing combined flow for catchment-scenario: "catchment3_scen"
# Writing combined flow for catchment-scenario: "catchment4_cntr"
# Writing combined flow for catchment-scenario: "catchment4_scen"
# Writing combined flow for catchment-scenario: "catchment5_cntr"
# Writing combined flow for catchment-scenario: "catchment5_scen"
# Writing combined flow for catchment-scenario: "catchment1_cntr"
# Writing combined flow for catchment-scenario: "catchment1_scen"
# Writing combined flow for catchment-scenario: "catchment2_cntr"
# Writing combined flow for catchment-scenario: "catchment2_scen"
# Writing combined flow for catchment-scenario: "catchment3_cntr"
# Writing combined flow for catchment-scenario: "catchment3_scen"
# Writing combined flow for catchment-scenario: "catchment4_cntr"
# Writing combined flow for catchment-scenario: "catchment4_scen"
# Writing combined flow for catchment-scenario: "catchment5_cntr"
# Writing combined flow for catchment-scenario: "catchment5_scen"
# Writing combined flow for catchment-scenario: "catchment1_cntr"
# Writing combined flow for catchment-scenario: "catchment1_scen"
# Writing combined flow for catchment-scenario: "catchment2_cntr"
# Writing combined flow for catchment-scenario: "catchment2_scen"
# Writing combined flow for catchment-scenario: "catchment3_cntr"
# Writing combined flow for catchment-scenario: "catchment3_scen"
# Writing combined flow for catchment-scenario: "catchment4_cntr"
# Writing combined flow for catchment-scenario: "catchment4_scen"
# Writing combined flow for catchment-scenario: "catchment5_cntr"
# Writing combined flow for catchment-scenario: "catchment5_scen"
# Writing combined flow for catchment-scenario: "catchment1_cntr"
# Writing combined flow for catchment-scenario: "catchment1_scen"
# Writing combined flow for catchment-scenario: "catchment2_cntr"
# Writing combined flow for catchment-scenario: "catchment2_scen"
# Writing combined flow for catchment-scenario: "catchment3_cntr"
# Writing combined flow for catchment-scenario: "catchment3_scen"
# Writing combined flow for catchment-scenario: "catchment4_cntr"
# Writing combined flow for catchment-scenario: "catchment4_scen"
# Writing combined flow for catchment-scenario: "catchment5_cntr"
# Writing combined flow for catchment-scenario: "catchment5_scen"
# Writing combined flow for catchment-scenario: "catchment1_cntr"
# Writing combined flow for catchment-scenario: "catchment1_scen"
# Writing combined flow for catchment-scenario: "catchment2_cntr"
# Writing combined flow for catchment-scenario: "catchment2_scen"
# Writing combined flow for catchment-scenario: "catchment3_cntr"
# Writing combined flow for catchment-scenario: "catchment3_scen"
# Writing combined flow for catchment-scenario: "catchment4_cntr"
# Writing combined flow for catchment-scenario: "catchment4_scen"
# Writing combined flow for catchment-scenario: "catchment5_cntr"
# Writing combined flow for catchment-scenario: "catchment5_scen"
